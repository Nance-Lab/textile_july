# %% [markdown]
# ### Intro To Image Processing: An Image As Numbers
#
# #### Purpose: To view an image from a computer perspective (as an array of numbers)

# %% [markdown]
# * step 1: Necessary Imports

# %%
import numpy as np
from skimage import io

import matplotlib.pyplot as plt

# %% [markdown]
# * step 2: User Inputs

# %%
cell_im_location = '/Users/julyzhou/Documents/GitHub/textile/example_data/ogd_cells.tif'

# %% [markdown]
# * step 3: Reading the image

# %%
cell_im = io.imread(cell_im_location)

# %% [markdown]
# * step 4: Viewing the image

# %%
cell_im.shape
# Out:
# (512, 512, 3)

# %%
red_cell_im = cell_im[:,:, 0]
green_cell_im = cell_im[:,:,1]
blue_cell_im = cell_im[:,:,2]

# %%
blue_cell_im
# Out:
# array([[ 0, 22, 16, ...,  1,  4,  5],
#        [ 0, 16, 11, ...,  5,  0,  8],
#        [ 5,  0, 11, ...,  3,  0, 16],
#        ...,
#        [ 4,  0, 17, ..., 19, 33, 13],
#        [ 0, 25, 49, ...,  8, 26, 44],
#        [ 3,  1,  1, ..., 20,  6, 25]], dtype=uint16)

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].imshow(red_cell_im, cmap='gray')
ax[0,0].get_xaxis().set_visible(False)
ax[1,0].imshow(green_cell_im, cmap='gray')
ax[0,1].imshow(blue_cell_im, cmap='gray')
ax[1,1].imshow(cell_im)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].imshow(red_cell_im, cmap='gray')
ax[0,0].get_xaxis().set_visible(False)
ax[0,0].get_yaxis().set_visible(False)
ax[0,0].set_title('Red Channel - PI')


ax[1,0].imshow(green_cell_im, cmap='gray')
ax[1,0].get_xaxis().set_visible(False)
ax[1,0].get_yaxis().set_visible(False)
ax[1,0].set_title('Green Channel - Iba')

ax[0,1].imshow(blue_cell_im, cmap='gray')
ax[0,1].get_xaxis().set_visible(False)
ax[0,1].get_yaxis().set_visible(False)
ax[0,1].set_title('Blue Channel - Dapi')

ax[1,1].imshow(cell_im)
ax[1,1].get_xaxis().set_visible(False)
ax[1,1].get_yaxis().set_visible(False)
ax[1,1].set_title('All Channels')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'All Channels')
